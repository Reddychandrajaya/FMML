# %% [markdown]
# <a href="https://colab.research.google.com/github/Reddychandrajaya/FMML/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-02 12:45:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   176MB/s    in 0.4s
#
# 2024-04-02 12:45:38 (176 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11762  1611.06585v2  We propose a black-box variational inference m...  stat
# 22245  1510.02354v1  We consider sequential decision making problem...  stat
# 7543   1802.02907v1  Distributed Support Vector Machines (DSVM) hav...  stat
# 34179  1612.08205v1  Automatic profiling of social media users is a...    cs
# 13848  1510.07163v1  The search ability of an Evolutionary Algorith...    cs
# ...             ...                                                ...   ...
# 5654   1604.01348v1  This paper presents a Bayesian optimization me...  stat
# 3132    1210.4872v1  A tree-based dictionary learning model is deve...    cs
# 3295    1412.6821v1  Topological data analysis offers a rich source...  stat
# 19136   1304.1146v1  After a brief introduction to causal probabili...    cs
# 5207    1201.3382v2  We consider the problem of using a factor mode...  stat
#
#                                                    title  year  \
# 11762  Variational Boosting: Iteratively Refining Pos...  2016
# 22245  The Knowledge Gradient with Logistic Belief Mo...  2015
# 7543   A Game-Theoretic Approach to Design Secure and...  2018
# 34179   Predicting the Industry of Users on Social Media  2016
# 13848  Evolutionary Landscape and Management of Popul...  2015
# ...                                                  ...   ...
# 5654   Bayesian Optimization with Exponential Converg...  2016
# 3132   Nested Dictionary Learning for Hierarchical Or...  2012
# 3295   A Stable Multi-Scale Kernel for Topological Ma...  2014
# 19136                 Analysis in HUGIN of Data Conflict  2013
# 5207   Spike-and-Slab Sparse Coding for Unsupervised ...  2012
#
#                                                 keywords
# 11762  [variational, inference, approximate, intracta...
# 22245  [sequential, classification, repeatedly, selec...
# 7543   [distributed, developed, classification, netwo...
# 34179  [automatic, profiling, important, supporting, ...
# 13848  [evolutionary, algorithm, variation, individua...
# ...                                                  ...
# 5654   [optimization, exponential, convergence, auxil...
# 3132   [dictionary, developed, associated, dictionary...
# 3295   [topological, information, theoretically, conn...
# 19136  [introduction, probabilistic, conflicting, dis...
# 5207   [classification, resembles, inference, intract...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11762    [variational, inference, approximate, intracta...
# 22245    [sequential, classification, repeatedly, selec...
# 7543     [distributed, developed, classification, netwo...
# 34179    [automatic, profiling, important, supporting, ...
# 13848    [evolutionary, algorithm, variation, individua...
#                                ...
# 18864    [operations, problematic, uncertainty, followi...
# 23041    [dimensionality, reduction, procedures, extens...
# 34230    [enhancing, classification, association, depen...
# 12921    [approximate, computation, synthetic, likeliho...
# 18775    [possibilistic, programming, programming, atta...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8814 words.
# Out of those 4531 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e080491f-90e8-496c-966b-7449f3a59212" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e080491f-90e8-496c-966b-7449f3a59212")) {                    Plotly.newPlot(                        "e080491f-90e8-496c-966b-7449f3a59212",                        [{"x":["intractable","approximating","synthetic","distributions","resulting","approximations","inference","iteratively","approximation","incorporating","statistical","computation","posterior","structure","variational","approximate","inferences","efficiency","practitioner","additional","favorably","introducing","algorithms","increasingly","covariance","components","optimization","experiments","knowledge","alternatives","effectiveness","expensive","benchmark","selecting","observations","sequential","maximizing","information","classification","experiment","regression","applications","motivated","estimated","consuming","repeatedly","alternative","demonstrate","formulating","difficult","guaranteed","corroborate","resilience","adversary","important","environments","theoretic","algorithm","assumptions","enhancing","detection","establish","processing","vulnerable","manipulate","topologies","distributed","developed","equilibrium","resilient","conducted","numerical","adversarial","framework","objective","conflicting","convergence","networked","predicting","interests","multitude","substantial","automatic","qualitative","collective","outperforming","downstream","attributes","engineering","supporting","perceived","profiling","addresses","expressed","significantly","diversity","introduces","premature","variation","solutions","particular","maintains","constructive","evolutionary","imperative","efficient","management","suboptimal","understanding","designing","implementation","functions","investigation","simulation","operations","technique","discouraging","unexplored","landscape","promising","population","maintaining","individuals","processes","commutative","prediction","euclidean","classical","forecasting","symmetric","permutations","operators","supervised","clustered","intervention","questions","discussion","communication","presented","preliminary","quantitative","phenomena","dimension","hypotheses","sentiment","community","exploratory","categories","investigated","carefully","perceptron","degradation","maintenance","component","department","application","simulations","multilayer","diagnosis","condition","evaluation","computational","eliminated","conventional","binarized","applicable","corrected","intensity","foreground","techniques","binarization","classified","background","characterized","communicate","continuous","properties","stability","discontinuous","parameters","increasing","following","probability","detecting","likelihood","traditional","reinforcement","artificial","description","intrinsic","capabilities","modulated","procedures","controlling","minimization","spatiotemporal","identical","stochastic","unsupervised","generalized"],"y":[22,14,135,113,159,37,206,39,104,54,156,148,33,313,53,108,15,169,2,117,16,57,590,50,20,105,336,614,330,28,194,66,218,48,86,88,23,706,558,69,118,453,64,64,33,10,97,547,11,167,32,5,5,7,342,76,40,751,65,24,334,40,315,14,13,12,116,170,18,1,82,85,103,548,160,10,118,5,79,16,2,50,198,59,12,34,12,78,55,21,9,4,61,37,277,41,71,3,52,132,262,11,10,58,5,395,50,17,158,46,132,225,35,73,75,259,1,4,15,110,45,37,37,93,0,234,33,102,18,28,9,50,204,10,14,66,36,57,179,47,77,24,62,22,57,73,10,82,60,36,21,16,11,126,3,224,43,11,56,39,225,306,8,103,6,49,6,31,22,389,9,25,73,23,11,108,223,38,7,250,98,86,168,76,73,181,117,131,85,47,50,6,35,17,69,13,17,124,136,68],"type":"bar"},{"x":["intractable","approximating","synthetic","distributions","resulting","approximations","inference", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4531,), (4531, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Novel</span> <span style=''>Way</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Identifying</span> <span style=''>Cyber</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Predators</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.45544554455445546);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>with</span> <span style=''>Long</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>Memory</span> <span style=''>cell</span> <span style=''>(LSTM</span> <span style=''>RNN)</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>impressive</span> <span style=''>ability</span> <span style=''>in</span> <span style=''>sequence</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.5254237288135593);'>processing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>for</span> <span style=''>language</span> <span style=''>model</span> <span style=''>building</span> <span style=''>and</span> <span style=''>text</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>This</span> <span style=''>research</span> <span style=''>proposes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combination</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5405405405405406);'>sentiment</span> <span style=''>analysis</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>of</span> <span style=''>sentence</span> <span style=''>vectors</span> <span style=''>and</span> <span style=''>LSTM</span> <span style=''>RNN</span> <span style=''>as</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>way</span> <span style=''>for</span> <span style=''>Sexual</span> <span style=''>Predator</span> <span style='background-color:rgba(0, 255, 0, 0.3107344632768362);'>Identification</span> <span style=''>(SPI)</span> <span style=''>LSTM</span> <span style=''>RNN</span> <span style=''>language</span> <span style=''>model</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>sentence</span> <span style=''>vectors</span> <span style=''>which</span> <span style=''>are</span> <span style=''>the</span> <span style=''>last</span> <span style=''>hidden</span> <span style=''>states</span> <span style=''>in</span> <span style=''>the</span> <span style=''>language</span> <span style=''>model</span> <span style=''>Sentence</span> <span style=''>vectors</span> <span style=''>are</span> <span style=''>fed</span> <span style=''>into</span> <span style=''>another</span> <span style=''>LSTM</span> <span style=''>RNN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>so</span> <span style=''>as</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>suspicious</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conversations</span> <span style=''>Hidden</span> <span style=''>state</span> <span style=''>enables</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>vectors</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.8999999999999999);'>sentences</span> <span style=''>never</span> <span style=''>seen</span> <span style=''>before</span> <span style=''>Fasttext</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style=''>filter</span> <span style=''>the</span> <span style=''>contents</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conversations</span> <span style=''>and</span> <span style=''>generate</span> <span style=''>a</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Computing</span> <span style=''>p</span> <span style=''>values</span> <span style=''>of</span> <span style=''>LiNGAM</span> <span style=''>outputs</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiscale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bootstrap</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style=''>equation</span> <span style=''>models</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>been</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>to</span> <span style=''>study</span> <span style=''>causal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Recently</span> <span style=''>a</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style=''>method</span> <span style=''>called</span> <span style=''>LiNGAM</span> <span style=''>was</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>discover</span> <span style=''>such</span> <span style=''>causal</span> <span style=''>models</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>extended</span> <span style=''>in</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>directions</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>LiNGAM</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>results</span> <span style=''>are</span> <span style=''>affected</span> <span style=''>by</span> <span style=''>the</span> <span style=''>random</span> <span style=''>sampling</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>as</span> <span style=''>with</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>method</span> <span style=''>Thus</span> <span style=''>some</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reliability</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>level</span> <span style=''>should</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducted</span> <span style=''>A</span> <span style=''>common</span> <span style=''>method</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>level</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>method</span> <span style=''>However</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>level</span> <span style=''>computed</span> <span style=''>by</span> <span style=''>ordinary</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bootstrap</span> <span style=''>method</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style=''>biased</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>value</span> <span style=''>(p</span> <span style=''>value)</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gaussian</span> <span style=''>Process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Bandit</span> <span style=''>Setting</span> <span style=''>No</span> <span style=''>Regret</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.36742424242424243);'>Experimental</span> <span style=''>Design</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>noisy</span> <span style=''>function</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.4000000000000001);'>formalize</span> <span style=''>this</span> <span style=''>task</span> <span style=''>as</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>payoff</span> <span style=''>function</span> <span style=''>is</span> <span style=''>either</span> <span style=''>sampled</span> <span style=''>from</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>or</span> <span style=''>has</span> <span style=''>low</span> <span style=''>RKHS</span> <span style=''>norm</span> <span style=''>We</span> <span style=''>resolve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>open</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>deriving</span> <span style=''>regret</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>which</span> <span style=''>imply</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3038348082595871);'>convergence</span> <span style=''>rates</span> <span style=''>for</span> <span style=''>GP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>GP</span> <span style=''>UCB</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style=''>upper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>confidence</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>bound</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style=''>regret</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>maximal</span> <span style='background-color:rgba(0, 255, 0, 0.30983302411873836);'>information</span> <span style=''>gain</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>establishing</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>between</span> <span style=''>GP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.36742424242424243);'>experimental</span> <span style=''>design</span> <span style=''>Moreover</span> <span style=''>by</span> <span style=''>bounding</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>operator</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Networks</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Pulmonary</span> <span style=''>Nodule</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>in</span> <span style=''>CT</span> <span style=''>Imaging</span> <br/><br/><span style=''>Computed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>tomography</span> <span style=''>(CT)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>a</span> <span style=''>stack</span> <span style=''>of</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sectional</span> <span style=''>images</span> <span style=''>covering</span> <span style=''>a</span> <span style=''>region</span> <span style=''>of</span> <span style=''>the</span> <span style=''>body</span> <span style=''>The</span> <span style=''>visual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assessment</span> <span style=''>of</span> <span style=''>these</span> <span style=''>images</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>identification</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>abnormalities</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>task</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>that</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processed</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>artificial</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>ReCTnet</span> <span style=''>for</span> <span style=''>the</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>pulmonary</span> <span style=''>nodules</span> <span style=''>in</span> <span style=''>CT</span> <span style=''>scans</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>learns</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distinguish</span> <span style=''>nodules</span> <span style=''>and</span> <span style=''>normal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>at</span> <span style=''>the</span> <span style=''>pixel</span> <span style=''>level</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>three</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>maps</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>highlighting</span> <span style=''>areas</span> <span style=''>that</span> <span style=''>are</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.12897463379778493)
# 	challenging (0.10003572704537335)
# 	segmentation (0.07109682029296177)
# 	architecture (0.0961057520543051)
# 	processing (0.11254019292604502)
# 	information (0.2522329403358342)
# 	detection (0.11932833154698107)
# 	convolutional (0.1400500178635227)
# 	recognition (0.14076455877098965)
# 	different (0.2704537334762415)
#
# Some Statistics words are:
# 	distributions (0.12493753123438281)
# 	variables (0.14392803598200898)
# 	theoretical (0.1549225387306347)
# 	statistical (0.1619190404797601)
# 	estimation (0.18140929535232383)
# 	inference (0.19590204897551225)
# 	algorithm (0.39480259870064965)
# 	distribution (0.19490254872563717)
# 	dimensional (0.19090454772613694)
# 	regression (0.1969015492253873)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f920a639-c978-450c-bedc-e83f995b29dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f920a639-c978-450c-bedc-e83f995b29dd")) {                    Plotly.newPlot(                        "f920a639-c978-450c-bedc-e83f995b29dd",                        [{"x":["intractable","approximating","synthetic","distributions","resulting","approximations","inference","iteratively","approximation","incorporating","statistical","computation","posterior","structure","variational","approximate","inferences","efficiency","practitioner","additional","favorably","introducing","algorithms","increasingly","covariance","components","optimization","experiments","knowledge","alternatives","effectiveness","expensive","benchmark","selecting","observations","sequential","maximizing","information","classification","experiment","regression","applications","motivated","estimated","consuming","repeatedly","alternative","demonstrate","formulating","difficult","guaranteed","corroborate","resilience","adversary","important","environments","theoretic","algorithm","assumptions","enhancing","detection","establish","processing","vulnerable","manipulate","topologies","distributed","developed","equilibrium","resilient","conducted","numerical","adversarial","framework","objective","conflicting","convergence","networked","predicting","interests","multitude","substantial","automatic","qualitative","collective","outperforming","downstream","attributes","engineering","supporting","perceived","profiling","addresses","expressed","significantly","diversity","introduces","premature","variation","solutions","particular","maintains","constructive","evolutionary","imperative","efficient","management","suboptimal","understanding","designing","implementation","functions","investigation","simulation","operations","technique","discouraging","unexplored","landscape","promising","population","maintaining","individuals","processes","commutative","prediction","euclidean","classical","forecasting","symmetric","permutations","operators","supervised","clustered","intervention","questions","discussion","communication","presented","preliminary","quantitative","phenomena","dimension","hypotheses","sentiment","community","exploratory","categories","investigated","carefully","perceptron","degradation","maintenance","component","department","application","simulations","multilayer","diagnosis","condition","evaluation","computational","eliminated","conventional","binarized","applicable","corrected","intensity","foreground","techniques","binarization","classified","background","characterized","communicate","continuous","properties","stability","discontinuous","parameters","increasing","following","probability","detecting","likelihood","traditional","reinforcement","artificial","description","intrinsic","capabilities","modulated","procedures","controlling","minimization","spatiotemporal","identical","stochastic","unsupervised","generalized","combination","formulate","evaluated","representations","invariant","randomized","integration","accelerate","complemented","sequences","characterizations","empirical","improving","theoretical","integrands","discrepancy","considered","inequalities","inequality","attention","estimator","investigate","predictors","dimensional","estimators","auxiliary","semantics","representation","generators","intuitively","competitive","arbitrarily","distribution","discrimination","generative","contemporary","projecting","approaches","empirically","demonstrated","compelling","bidirectional","proximity","correlated","attribute","importance","embeddings","incomplete","nonetheless","overwhelmingly","consensus","extensive","leverages","manifested","correlations","inherently","per ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	commutative
# 	integrands
# 	forthcoming
# 	ancestral
# 	supermarket
# 	parametrically
# 	resamples
# 	penalised
# 	nonnegativity
# 	changepoint
# 	radiological
# 	exchangeability
# 	overconfident
# 	preconditioning
# 	preconditioned
# 	macroeconomic
# 	faithfulness
# 	confounded
# 	confounders
# 	particulars
# Some words which never appear in Statistics papers:
# 	discontinuous
# 	overwhelmingly
# 	describable
# 	prioritization
# 	catalogues
# 	experimented
# 	decidable
# 	subsuming
# 	congestion
# 	coreference
# 	continually
# 	tendencies
# 	photoshop
# 	selectively
# 	disambiguating
# 	copyright
# 	strategically
# 	forgeries
# 	infringement
# 	reviewers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.074936195073952e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
